# %%
import folium
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/jdvelasq/datalabs/master/datasets/scopus-papers.csv")
df.head(2)
# Out:
#                                              Authors  \
# 0                     Roy K.C., Cebrian M., Hasan S.
# 1  Alizadeh M., Weber I., Cioffi-Revilla C., Fort...
#
#                                         Author(s) ID  \
# 0                57208923159;8724466500;55166094600;
# 1  56400437200;8943847500;6603233416;7005680829;5...
#
#                                                Title  Year      Source title  \
# 0  Quantifying human mobility resilience to extre...  2019  EPJ Data Science
# 1  Psychology and morality of political extremist...  2019  EPJ Data Science
#
#    Volume Issue Art. No. Page start Page end  ...  \
# 0     8.0     1       18        NaN      NaN  ...
# 1     8.0     1       17        NaN      NaN  ...
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                         Affiliations  \
# ...
